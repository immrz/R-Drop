# %%
import os
os.chdir("/home/v-runmao/projects/R-Drop/vit_src/")

# %%
import timm
from timm.data import resolve_data_config
from timm.data.transforms_factory import create_transform

import torch
from torch.utils.data import DataLoader
import torchvision.datasets as datasets

from tqdm.auto import tqdm

# %% [markdown]
# # Test the rw_m model

# %%
# create model
m = timm.create_model("efficientnetv2_rw_m", pretrained=True).to("cuda:0")

# %%
# check the depth of each stage
for i, stage in enumerate(m.blocks):
    print(f"{i}-th stage:", len(stage))
# Out:
# 0-th stage: 3
# 1-th stage: 5
# 2-th stage: 5
# 3-th stage: 8
# 4-th stage: 15
# 5-th stage: 24

# %%
# create transforms
xsfm_cfg = resolve_data_config({}, model=m, use_test_size=True)
transform = create_transform(**xsfm_cfg)
print("cfg: ", xsfm_cfg)
print("transform: ", transform)
# Out:
# cfg:  {'input_size': (3, 416, 416), 'interpolation': 'bicubic', 'mean': (0.485, 0.456, 0.406), 'std': (0.229, 0.224, 0.225), 'crop_pct': 1.0}
# transform:  Compose(
#     Resize(size=416, interpolation=bicubic)
#     CenterCrop(size=(416, 416))
#     ToTensor()
#     Normalize(mean=tensor([0.4850, 0.4560, 0.4060]), std=tensor([0.2290, 0.2240, 0.2250]))
# )
# /anaconda/envs/rdrop/lib/python3.8/site-packages/torchvision/transforms/transforms.py:257: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(

# %%
# create imagenet validation set
imgnet_val = datasets.ImageFolder("/scratch/ILSVRC2012/val", transform=transform)

# try to get the first instance
instance = imgnet_val[0]
print(instance)
# Out:
# (tensor([[[ 1.4954,  0.5536,  1.4612,  ...,  0.9646, -0.0801,  0.4679],
#          [ 1.8893,  1.1872,  0.0569,  ..., -0.2171,  0.5022,  0.9646],
#          [ 1.7865,  1.5639, -0.4568,  ...,  0.5707,  0.9303,  0.8789],
#          ...,
#          [-0.4226, -0.4739, -0.4397,  ...,  0.1939, -0.2684, -0.3369],
#          [-0.3712, -0.4739, -0.2513,  ..., -0.2342, -0.1828, -0.0116],
#          [-0.3369, -0.4568, -0.4226,  ..., -0.1999, -0.2171, -0.1143]],
#
#         [[ 1.0455,  0.3978,  1.1331,  ...,  1.3957,  0.1352,  0.8004],
#          [ 1.7633,  1.0105, -0.2675,  ..., -0.1275,  0.8004,  1.4132],
#          [ 1.3957,  1.2556, -0.7752,  ...,  0.7479,  1.2381,  1.1155],
#          ...,
#          [ 0.1702,  0.0826,  0.1527,  ...,  0.4328, -0.2325, -0.2500],
#          [ 0.2752,  0.1001,  0.1001,  ..., -0.0749,  0.1702,  0.2052],
#          [ 0.0476, -0.0399, -0.0749,  ...,  0.1527,  0.0826,  0.1877]],
#
#         [[ 0.3568,  0.3219,  0.6356,  ...,  1.0888,  0.4788,  1.1411],
#          [ 0.8099,  0.3916,  0.0779,  ...,  0.0779,  0.7054,  1.1411],
#          [ 0.3393,  0.4614, -0.3230,  ...,  0.7751,  1.0365,  0.9319],
#          ...,
#          [ 0.4614,  0.4439,  0.4614,  ...,  0.4962, -0.1487, -0.4101],
#          [ 0.6008,  0.4788,  0.4788,  ..., -0.1487, -0.2881, -0.2532],
#          [ 0.4265,  0.3568,  0.2871,  ..., -0.1487, -0.2881, -0.1835]]]), 0)

# %%
# create loader
loader = DataLoader(imgnet_val, batch_size=256, num_workers=4, pin_memory=True)

# try to get the first batch
x, y = next(iter(loader))
print(x.shape)
print(y.shape)
# Out:
# torch.Size([256, 3, 416, 416])
# torch.Size([256])

# %%
def evaluate(model, loader):
    all_y = []
    all_pred = []
    
    model.eval()
    for x, y in tqdm(loader):
        logits = model(x.to("cuda:0"))
        pred = logits.argmax(1).cpu()
        all_y.append(y)
        all_pred.append(pred)
    
    all_y = torch.cat(all_y, dim=0)
    all_pred = torch.cat(all_pred, dim=0)
    n_samples = all_y.size(0)
    n_correct = (all_y == all_pred).sum()
    
    print(f"Evaluation ends. Totally {n_samples} samples.")
    print(f"Accuracy is {n_correct * 100 / n_samples}%.")
    return n_correct / n_samples, all_y, all_pred

# %%
# validation
with torch.no_grad():
    acc, y, pred = evaluate(m, loader)
# Out:
#   0%|          | 0/196 [00:00<?, ?it/s]
# Evaluation ends. Totally 50000 samples.
# Accuracy is 84.81199645996094%.

# %% [markdown]
# # Test the TensorFlow compatible model

# %%
m = timm.create_model("tf_efficientnetv2_m", pretrained=True).to("cuda:0")
for i, stage in enumerate(m.blocks):
    print(f"{i}-th stage:", len(stage))

xsfm_cfg = resolve_data_config({}, model=m, use_test_size=True)
transform = create_transform(is_training=False, **xsfm_cfg)
print("Test cfg: ", xsfm_cfg)
print("Test transform: ", transform)

xsfm_cfg = resolve_data_config({}, model=m, use_test_size=False)
transform = create_transform(is_training=True, **xsfm_cfg)
print("Train cfg: ", xsfm_cfg)
print("Train transform: ", transform)

imgnet_val = datasets.ImageFolder("/scratch/ILSVRC2012/val", transform=transform)
loader = DataLoader(imgnet_val, batch_size=256, num_workers=4, pin_memory=True)

x, y = next(iter(loader))
print(x.shape)
print(y.shape)
# Out:
# 0-th stage: 3
# 1-th stage: 5
# 2-th stage: 5
# 3-th stage: 7
# 4-th stage: 14
# 5-th stage: 18
# 6-th stage: 5
# Test cfg:  {'input_size': (3, 480, 480), 'interpolation': 'bicubic', 'mean': (0.5, 0.5, 0.5), 'std': (0.5, 0.5, 0.5), 'crop_pct': 1.0}
# Test transform:  Compose(
#     Resize(size=480, interpolation=bicubic)
#     CenterCrop(size=(480, 480))
#     ToTensor()
#     Normalize(mean=tensor([0.5000, 0.5000, 0.5000]), std=tensor([0.5000, 0.5000, 0.5000]))
# )
# Train cfg:  {'input_size': (3, 384, 384), 'interpolation': 'bicubic', 'mean': (0.5, 0.5, 0.5), 'std': (0.5, 0.5, 0.5), 'crop_pct': 1.0}
# Train transform:  Compose(
#     RandomResizedCropAndInterpolation(size=(384, 384), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BICUBIC)
#     RandomHorizontalFlip(p=0.5)
#     ColorJitter(brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=None)
#     ToTensor()
#     Normalize(mean=tensor([0.5000, 0.5000, 0.5000]), std=tensor([0.5000, 0.5000, 0.5000]))
# )
# /anaconda/envs/rdrop/lib/python3.8/site-packages/torchvision/transforms/transforms.py:257: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /anaconda/envs/rdrop/lib/python3.8/site-packages/torchvision/transforms/functional.py:364: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /anaconda/envs/rdrop/lib/python3.8/site-packages/torchvision/transforms/functional.py:364: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /anaconda/envs/rdrop/lib/python3.8/site-packages/torchvision/transforms/functional.py:364: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /anaconda/envs/rdrop/lib/python3.8/site-packages/torchvision/transforms/functional.py:364: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# torch.Size([256, 3, 384, 384])
# torch.Size([256])

# %%
with torch.no_grad():
    acc, y, pred = evaluate(m, loader)
# Out:
#   0%|          | 0/196 [00:00<?, ?it/s]
# Evaluation ends. Totally 50000 samples.
# Accuracy is 85.04399871826172%.

# %% [markdown]
# # Use official model and use hook to get intermediate outputs

# %%
m = timm.create_model("tf_efficientnetv2_m",
                      pretrained=True,
                      num_classes=100,
                      drop_rate=0.4,
                      drop_path_rate=0.2).to("cuda:0")
display(m)
# Out:
# EfficientNet(
#   (conv_stem): Conv2dSame(3, 24, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): SiLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#       )
#       (1): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#       )
#       (2): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#       )
#     )
#     (1): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2dSame(24, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): EdgeResidual(
#         (conv_exp): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): EdgeResidual(
#         (conv_exp): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): EdgeResidual(
#         (conv_exp): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): EdgeResidual(
#         (conv_exp): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2dSame(48, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): EdgeResidual(
#         (conv_exp): Conv2d(80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): EdgeResidual(
#         (conv_exp): Conv2d(80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): EdgeResidual(
#         (conv_exp): Conv2d(80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): EdgeResidual(
#         (conv_exp): Conv2d(80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(80, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2dSame(320, 320, kernel_size=(3, 3), stride=(2, 2), groups=320, bias=False)
#         (bn2): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(320, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 320, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#         (bn2): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(640, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 640, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#         (bn2): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(640, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 640, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#         (bn2): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(640, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 640, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#         (bn2): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(640, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 640, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#         (bn2): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(640, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 640, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): InvertedResidual(
#         (conv_pw): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#         (bn2): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(640, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 640, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (10): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (11): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (12): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (13): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2dSame(1056, 1056, kernel_size=(3, 3), stride=(2, 2), groups=1056, bias=False)
#         (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1056, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (10): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (11): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (12): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (13): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (14): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (15): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (16): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (17): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#         (bn2): BatchNorm2d(1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1824, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#         (bn2): BatchNorm2d(3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(3072, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(128, 3072, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#         (bn2): BatchNorm2d(3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(3072, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(128, 3072, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#         (bn2): BatchNorm2d(3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(3072, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(128, 3072, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#         (bn2): BatchNorm2d(3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(3072, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(128, 3072, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv_head): Conv2d(512, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNorm2d(1280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (act2): SiLU(inplace=True)
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Linear(in_features=1280, out_features=100, bias=True)
# )

# %% [markdown]
# ## drop_path_rate

# %%
print(len([_block for _stage in m.blocks for _block in _stage]))
print(m.drop_rate)
blocks = [b for stage in m.blocks for b in stage]
for i, block in enumerate(blocks):
    print(f"{i}, {block.__class__}, {block.drop_path_rate}")
# Out:
# 57
# 0.4
# 0, <class 'timm.models.efficientnet_blocks.ConvBnAct'>, 0.0
# 1, <class 'timm.models.efficientnet_blocks.ConvBnAct'>, 0.0035087719298245615
# 2, <class 'timm.models.efficientnet_blocks.ConvBnAct'>, 0.007017543859649123
# 3, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.010526315789473686
# 4, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.014035087719298246
# 5, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.017543859649122806
# 6, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.02105263157894737
# 7, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.024561403508771933
# 8, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.028070175438596492
# 9, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.031578947368421054
# 10, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.03508771929824561
# 11, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.03859649122807018
# 12, <class 'timm.models.efficientnet_blocks.EdgeResidual'>, 0.04210526315789474
# 13, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.0456140350877193
# 14, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.04912280701754387
# 15, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.05263157894736842
# 16, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.056140350877192984
# 17, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.05964912280701755
# 18, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.06315789473684211
# 19, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.06666666666666667
# 20, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.07017543859649122
# 21, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.0736842105263158
# 22, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.07719298245614035
# 23, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.08070175438596493
# 24, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.08421052631578949
# 25, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.08771929824561403
# 26, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.0912280701754386
# 27, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.09473684210526316
# 28, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.09824561403508773
# 29, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.10175438596491229
# 30, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.10526315789473684
# 31, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.10877192982456141
# 32, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.11228070175438597
# 33, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.11578947368421054
# 34, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.1192982456140351
# 35, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.12280701754385964
# 36, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.12631578947368421
# 37, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.1298245614035088
# 38, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.13333333333333333
# 39, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.1368421052631579
# 40, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.14035087719298245
# 41, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.14385964912280705
# 42, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.1473684210526316
# 43, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.15087719298245614
# 44, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.1543859649122807
# 45, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.15789473684210525
# 46, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.16140350877192985
# 47, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.1649122807017544
# 48, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.16842105263157897
# 49, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.17192982456140352
# 50, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.17543859649122806
# 51, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.17894736842105266
# 52, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.1824561403508772
# 53, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.18596491228070178
# 54, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.18947368421052632
# 55, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.19298245614035087
# 56, <class 'timm.models.efficientnet_blocks.InvertedResidual'>, 0.19649122807017547
# Bad pipe message: %s [b'\xed\x12eV\xb67\x14p\xa0E\xc05\x83\x86\x0ei\xfe\x02 \x11\xc4hI\r\x92\xe3&\xae\x88=>\x12\x9dx\x02\x0c\xc3\xd4\x17\x02\x00\xfc:\x19\x06\x14(\xc9\xcf\x08~\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \xf48\x15\xaf\xe2m\xe7\xf3\xb3\xef']
# Bad pipe message: %s [b'\x142p]\xec\x8a\xb1M_\x98\xb1Td\x90\xc7\xaa\xe7h\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0']
# Bad pipe message: %s [b"\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00"]
# Bad pipe message: %s [b'0\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08']
# Bad pipe message: %s [b'\t\x08\n\x08\x0b\x08\x04']
# Bad pipe message: %s [b'\x08\x06\x04\x01\x05\x01\x06', b'', b'\x03\x03']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\xfd\xb2\x15\r\t\xec,9y\xbd\xeb\xe7\x83A\xbb\xab\xfbs\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0', b"w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t"]
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'7.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x03\x03\x02\x03\x03\x01\x02\x01\x03\x02\x02\x02\x04\x02\x05\x02\x06\x02']
# Bad pipe message: %s [b'6\x15S~r\x99c\xf2k\x95+\xe9\x98,lkM\x10\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08']
# Bad pipe message: %s [b"\xfa\xb2O\xd0\x8e(\xb6,\xb1\x0e\xb5\xd7\x17~'\x85\x04\x8b\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t", b'7.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00']
# Bad pipe message: %s [b'\x92*p\xeb\xe0G\xb3\x88\x84+u\xe64yY\xc9x;\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00', b'\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00']
# Bad pipe message: %s [b'\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\x17I\x18C\x8c\x12\xd9e\x7f:\xa8z5\x90j\x0e\x93U\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00']
# Bad pipe message: %s [b"\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b"]
# Bad pipe message: %s [b'\x13\xad\x15XS\xed\xa7']
# Bad pipe message: %s [b'\x9eDI\xb6H\xe852\xd9\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x00', b"7\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4"]

# %% [markdown]
# ## register hook

# %%
def get_embedding(module, input, output):
    m.pool_embedding = output
m.global_pool.register_forward_hook(get_embedding)

# %%
hasattr(m, "pool_embedding")
# Out:
# False

# %%
x = torch.randn(1, 3, 480, 480)
logits = m(x.to("cuda:0"))

# %%
hasattr(m, "pool_embedding")
# Out:
# True

# %%
display(m.pool_embedding)
print(m.pool_embedding.shape)
# Out:
# tensor([[0.0488, 0.0625, 0.0523,  ..., 0.0444, 0.0600, 0.0493]],
#        device='cuda:0', grad_fn=<ViewBackward>)
# torch.Size([1, 1280])

# %%
print(m.global_pool.pool_type, m.global_pool.flatten, m.global_pool.pool)
# Out:
# avg Flatten(start_dim=1, end_dim=-1) AdaptiveAvgPool2d(output_size=1)
